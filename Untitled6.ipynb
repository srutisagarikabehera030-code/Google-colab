# %% [markdown]
# <a href="https://colab.research.google.com/github/srutisagarikabehera030-code/Google-colab/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# students = ["Alice", "Bob", "Charlie", "David", "Emma"]

print("Student Names:")
for name in  students :
     print(name)
# Out:
# Student Names:
# Alice
# Bob
# Charlie
# David
# Emma

# %%
# numbers = [10, 20, 30, 40, 50]

print("First element:", numbers[0])
print("Last element:", numbers[-1])

# %%
# fruits = ["Apple", "Banana", "Mango", "Orange"]

# Add a new fruit
fruits.append("Grapes")

# Display the updated list
print("Updated list of fruits:", fruits)

# %%
subjects = ["Math", "Science", "English", "History"]

# Insert "AI" at the third position
subjects.insert(2, "AI")

# Display the updated list
print("Updated subjects list:", subjects)

# %%
numbers = [10, 20, 30, 40, 50]

# Remove the third element
numbers.pop(2)

# Display the updated list
print("Updated list:", numbers)

# %%
numbers = [10, 20, 30, 40, 50]

# Display required information
print("Length of the list:", len(numbers))
print("Maximum value:", max(numbers))
print("Minimum value:", min(numbers))
print("Sum of all elements:", sum(numbers))

# %%
numbers = []

for i in range(5):
    num = int(input(f"Enter number {i + 1}: "))
    numbers.append(num)

print("Complete list:", numbers)

# %%
cities = ["Mumbai", "Delhi", "Kolkata", "Chennai", "Bangalore"]

if "Delhi" in cities:
    print("Delhi exists in the list.")
else:
    print("Delhi does not exist in the list.")
