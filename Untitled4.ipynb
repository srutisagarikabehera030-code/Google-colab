# %% [markdown]
# <a href="https://colab.research.google.com/github/srutisagarikabehera030-code/Google-colab/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Q1. Student Name in Uppercase

name = input("Enter student name: ")
print("Uppercase Name:", name.upper())
# Out:
# Enter student name: Sruti
# Uppercase Name: SRUTI

# %%
# Q2. City Name Formatting

city = input("Enter city name: ")

print("Original Name:", city)
print("Uppercase:", city.upper())
print("Lowercase:", city.lower())
print("Title Case:", city.title())
# Out:
# Enter city name: Berhampur
# Original Name: Berhampur
# Uppercase: BERHAMPUR
# Lowercase: berhampur
# Title Case: Berhampur

# %%
# Q3. Length of a String

text = input("Enter a string: ")
print("Total Length:", len(text))
# Out:
# Enter a string: 20
# Total Length: 2

# %%
# Q4. First and Last Character

text = input("Enter a string: ")

print("First Character:", text[0])
print("Last Character:", text[-1])
# Out:
# Enter a string: 22
# First Character: 2
# Last Character: 2

# %%
# Q5. Count Letter 'a'

text = input("Enter a string: ")
print("Count of 'a':", text.count('a'))
# Out:
# Enter a string: 65
# Count of 'a': 0

# %%
# Q6. Replace "Python" with "AI"

sentence = input("Enter a sentence: ")
print(sentence.replace("Python", "AI"))
# Out:
# Enter a sentence: Hello
# Hello

# %%
# Q7. Check Gmail Address

email = input("Enter email address: ")

if email.endswith("@gmail.com"):
    print("Valid Gmail Address")
else:
    print("Not a Gmail Address")
# Out:
# Enter email address: hgggjhjvv.@gmail.com
# Valid Gmail Address

# %%
# Q8. Check Digits Only

text = input("Enter input: ")

if text.isdigit():
    print("Contains only digits")
else:
    print("Does not contain only digits")
# Out:
# Enter input: Good Morning
# Does not contain only digits

# %%
# Q9. Check Alphabets Only

text = input("Enter input: ")

if text.isalpha():
    print("Contains only alphabets")
else:
    print("Does not contain only alphabets")

# %%
# Q10. Split String into List

fruits = "Apple,Mango,Banana,Orange"
print(fruits.split(","))

# %%
# Q11. Voting Eligibility

age = int(input("Enter age: "))

if age >= 18:
    print("Eligible to Vote")
else:
    print("Not Eligible to Vote")

# %%
# Q12. Positive, Negative or Zero

num = int(input("Enter a number: "))

if num > 0:
    print("Positive")
elif num < 0:
    print("Negative")
else:
    print("Zero")

# %%
# Q13. Greater Between Two Numbers

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

if a > b:
    print("Greater Number:", a)
else:
    print("Greater Number:", b)

# %%
# Q14. Grade Assignment

marks = int(input("Enter marks: "))

if 90 <= marks <= 100:
    print("Grade A")
elif 75 <= marks <= 89:
    print("Grade B")
elif 50 <= marks <= 74:
    print("Grade C")
else:
    print("Fail")

# %%
# Q15. Even or Odd

num = int(input("Enter a number: "))

if num % 2 == 0:
    print("Even")
else:
    print("Odd")

# %%
# Q16. Strong or Weak Password

password = input("Enter password: ")

if len(password) >= 8:
    print("Strong Password")
else:
    print("Weak Password")

# %%
# Q17. Leap Year Check

year = int(input("Enter year: "))

if (year % 400 == 0) or (year % 4 == 0 and year % 100 != 0):
    print("Leap Year")
else:
    print("Not a Leap Year")

# %%
# Q18. Largest Among Three Numbers

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

if a >= b and a >= c:
    print("Largest:", a)
elif b >= a and b >= c:
    print("Largest:", b)
else:
    print("Largest:", c)

# %%
# Q19. Login Validation

username = input("Enter username: ")
password = input("Enter password: ")

if username == "admin" and password == "1234":
    print("Login Successful")
else:
    print("Invalid Credentials")

# %%
# Q20. Simple Calculator

num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
op = input("Enter operator (+, -, *, /): ")

if op == "+":
    print("Result =", num1 + num2)
elif op == "-":
    print("Result =", num1 - num2)
elif op == "*":
    print("Result =", num1 * num2)
elif op == "/":
    print("Result =", num1 / num2)
else:
    print("Invalid Operator")
# Out:
# Enter first number: 5
# Enter second number: 8
# Enter operator (+, -, *, /): +
# Result = 13.0
